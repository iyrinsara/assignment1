# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Saju Vargeese\\Downloads'

# %%
#Read the dataset to python environment

# %%
import pandas as pd
import seaborn as sns
data=pd.read_excel('iris.xls')
iris_data=pd.DataFrame(data)
print(iris_data)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Display the columns in the dataset

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
#Calculate the mean of each column of the dataset.

# %%
np.mean(data)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
#Check for the null values present in the dataset.

# %%
iris_data.isnull().values.any()
# Out:
# False

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
data=pd.read_excel('iris.xls')
iris_data=pd.DataFrame(data)

# %%
#Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
plt.figure(figsize=(8,8))
sns.heatmap(iris_data.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SL'),
#   Text(1.5, 0, 'SW'),
#   Text(2.5, 0, 'PL'),
#   Text(3.5, 0, 'PW')])

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=iris_data['SL'],y=iris_data['SW'],hue=iris_data['Classification'])
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=iris_data['PL'],y=iris_data['PW'],hue=iris_data['Classification'])
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=iris_data['SL'],y=iris_data['PW'],hue=iris_data['Classification'])
# Out:
# <AxesSubplot:xlabel='SL', ylabel='PW'>

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=iris_data['SW'],y=iris_data['PL'],hue=iris_data['Classification'])
# Out:
# <AxesSubplot:xlabel='SW', ylabel='PL'>
