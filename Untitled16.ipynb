# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Dataset_w6.xlsx')
data.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia              652864
# 1              Albania  SouthernEurope               28748
# 2              Algeria  NorthernAfrica             2381741
# 3               Angola    MiddleAfrica             1246700
# 4  Antigua and Barbuda       Caribbean                 442
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                           35530                         623.2
# 1                            2930                        3984.2
# 2                           41318                        4154.1
# 3                           29784                        4714.1
# 4                             102                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                             125                                        3568
# ...

# %%
data['country'].nunique()
# Out:
# 196

# %%
#2

# %%
sns.barplot(x='Region',y='GDP per capita (current US$)', data=data)
plt.xticks(rotation=270);

# %%
sns.barplot(x='Region',y='International trade: Imports (million US$)', data=data)
plt.xticks(rotation=270);

# %%
sns.heatmap(data.drop(['country','Region','Surface area (km2)'],axis=1).corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #3

# %%
data.groupby('Region')['country'].nunique()
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %%
#4

# %%
GDP=data.groupby('Region')['GDP per capita (current US$)'].mean()
GDP.nlargest(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %%
ITI = data.groupby('Region')['International trade: Imports (million US$)'].mean()
ITI.nlargest(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %%
#5

# %%
GDP_var =data.groupby('Region')['GDP per capita (current US$)'].std()
GDP_var.nsmallest(1)
# Out:
# Region
# WesternAfrica    815.095399
# Name: GDP per capita (current US$), dtype: float64
